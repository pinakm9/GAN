# %% [markdown]
# ### **Learning attractors**

# %%
# run this cell to download data and necessary modules
import os, shutil
repo = 'GAN'
if os.path.isdir(repo):
  shutil.rmtree(repo)
# !git clone https://github.com/pinakm9/GAN.git
# add modules folder to Python's search path
import sys
sys.path.insert(0, repo + '/modules')
# import the necessary modules
import num_gan as ng
import numpy as np
import tensorflow as tf
import random
from IPython.display import Image
import matplotlib.pyplot as plt
# Out:
# Cloning into 'GAN'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 46 (delta 7), reused 44 (delta 5), pack-reused 0
# Unpacking objects: 100% (46/46), done.

# %% [markdown]
# **Load the L63 attractor**

# %%
data_folder = '{}/experiments/learning attractors/attractors'.format(repo)
attractor = np.genfromtxt('{}/attractor_l63_1000_500.csv'.format(data_folder), dtype=np.float32, delimiter=',')
random.shuffle(attractor)

# %% [markdown]
# **Create a Generative Adversarial Network to "learn" the attractor**

# %%
n = 5000
noise = tf.random.normal([n, 2])
gen = l63_gan.generator(noise, training=False)

fig = plt.figure(figsize=(16, 8))
ax1 = fig.add_subplot(121, projection='3d')
ax1.scatter(gen[:, 0], gen[:, 1], gen[:, 2], label='generated', s=5.0)
ax1.set_title('generated')
ax2 = fig.add_subplot(122, projection='3d')
ax2.scatter(attractor[0:n, 0], attractor[0:n, 1], attractor[0:n, 2], label='true', s=5.0)
ax2.set_title('true attractor')
plt.legend()
plt.show()

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sun Jan 16 12:48:36 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    32W / 250W |    451MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

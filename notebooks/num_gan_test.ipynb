# %%
import sys
from pathlib import Path
from os.path import dirname, realpath, abspath
script_dir = Path(abspath(''))
module_dir = str(script_dir.parent)
sys.path.insert(0, module_dir + '/modules')
print(module_dir)

import num_gan as ng
import numpy as np
import tensorflow as tf
# Out:
# C:\Users\pinak\Documents\GitHub\GAN

# %%
x = 100.*(np.random.random_sample((10000,))-0.5)
y = x**2 + 10.
data = np.array(list(zip(list(x), list(y))))
dataset = np.array([data, data, data])
train_dataset = tf.data.Dataset.from_tensor_slices(data).batch(1000)

# %%
h =ng.NumGAN(16, 3, 2, 2)

# %%
h.train(train_dataset, 8000)
# Out:
# Time for epoch 100 is 0.04719734191894531 sec
# tf.Tensor(1.9225719, shape=(), dtype=float32) tf.Tensor(1.069137, shape=(), dtype=float32)
# Time for epoch 100 is 0.1726057529449463 sec
# tf.Tensor(1.2364969, shape=(), dtype=float32) tf.Tensor(1.1349565, shape=(), dtype=float32)
# Time for epoch 100 is 0.26676034927368164 sec
# tf.Tensor(2.1529014, shape=(), dtype=float32) tf.Tensor(1.1324944, shape=(), dtype=float32)
# Time for epoch 100 is 0.36092567443847656 sec
# tf.Tensor(0.8323405, shape=(), dtype=float32) tf.Tensor(1.4844984, shape=(), dtype=float32)
# Time for epoch 100 is 0.45505690574645996 sec
# tf.Tensor(2.6671073, shape=(), dtype=float32) tf.Tensor(1.6476866, shape=(), dtype=float32)
# Time for epoch 100 is 0.646000862121582 sec
# tf.Tensor(0.07777593, shape=(), dtype=float32) tf.Tensor(6.153646, shape=(), dtype=float32)
# Time for epoch 100 is 0.7536840438842773 sec
# tf.Tensor(0.4280028, shape=(), dtype=float32) tf.Tensor(2.3519068, shape=(), dtype=float32)
# ...

# %%
data
# Out:
# array([[  11.51841604,  142.67390814],
#        [   5.06353858,   35.63942299],
#        [   1.99439102,   13.97759552],
#        ...,
#        [  40.23961786, 1629.22684578],
#        [ -11.3898823 ,  139.72941869],
#        [  15.92717013,  263.67474826]])

# %%
import matplotlib.pyplot as plt
plt.scatter(x, y)

# %%
mask = np.array([1, 0, 1])

# %%
x = np.array([3, 2, 1])

# %%
tf.math.multiply(mask, x)
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([3, 0, 1])>
